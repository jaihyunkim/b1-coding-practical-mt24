# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','uuv_mission')))
print(sys.path)
# Out:
# ['/usr/local/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/usr/local/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/usr/local/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/jaihyunkim/.venvs/b1a-venv/lib/python3.13/site-packages', '/Users/jaihyunkim/Eng/B1_Repos/b1-coding-practical-mt24/uuv_mission']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant module
import dynamic
import control

import numpy as np
import random

# Set seed for Python and NumPy to ensure consistent results
#random.seed(42)
#np.random.seed(42)


sub = dynamic.Submarine()
# Instantiate your controller (depending on your implementation)
controller = control.PDController(Kp = 0.18, Kd = 0.6)

closed_loop = dynamic.ClosedLoop(sub, controller)
mission = dynamic.Mission.from_csv("/Users/jaihyunkim/Eng/B1_Repos/b1-coding-practical-mt24/data/mission.csv")

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)

# %%
# Import relevant module
import dynamic
import control

import numpy as np
import random

# Set seed for Python and NumPy to ensure consistent results
#random.seed(42)
#np.random.seed(42)


sub = dynamic.Submarine()
# Instantiate your controller (depending on your implementation)
controller = control.PDController(Kp = 0.18, Kd = 0.7)

closed_loop = dynamic.ClosedLoop(sub, controller)
mission = dynamic.Mission.random_mission(100, 50)

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
